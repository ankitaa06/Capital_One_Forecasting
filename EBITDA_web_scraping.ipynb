# %%
import pandas as pd
from selenium import webdriver
import time
from nltk.corpus import stopwords
import gensim
from gensim import corpora, models
from pprint import pprint
from nltk.corpus import wordnet as wn
from itertools import product
import csv
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome("/Users/akanksha_rajput/chromedriver")
driver.get("""https://www.macrotrends.net/stocks/charts/CABO/cable-one/ebitda""")
companies = pd.read_excel("/Users/akanksha_rajput/Downloads/Name.xls")

flag = True
f1 = 1


with open(r"/Users/akanksha_rajput/Documents/abc.csv","w") as f:

    for company in companies["AMC ENTERTAINMENT HLDS-CL A"]:
        url = company +" - EBITDA"
        
        
        if f1 ==1:
            if url != "H&R BLOCK INC - EBITDA":
                continue
            else:
                print("changed")
                f1 = 0
        print(url)    

        inputElement = driver.find_element_by_xpath("/html/body/div[1]/div[1]/div/div[3]/form/div[1]/div[1]/span[1]/input")
        #print(url)
        inputElement.send_keys(url)
        time.sleep(3)
        ie = WebDriverWait(driver,45).until(EC.presence_of_element_located((By.XPATH, "/html/body/div[1]/div[1]/div/div[3]/form/div[1]/div[2]/ul/li[1]")))
        
   
        ie.click()
        time.sleep(5)


        df_qr = {}
 
        qr = []
        val = []
        for i in range(1,27):
            #print(i)
            u1 = """//*[@id="style-1"]/div[2]/table/tbody/tr[""" + str(i) + """]/td[1]"""     
            u2 = """//*[@id="style-1"]/div[2]/table/tbody/tr[""" + str(i) + """]/td[2]"""
            try:
                qr.append(driver.find_element_by_xpath(u1).text)
                val.append(driver.find_element_by_xpath(u2).text)
            except:
                qr.append("")
                val.append("")
            
        df_qr["Quarter"] = qr
        df_qr[company] = val
        if flag:
            df1 = qr_data
            flag = False
        else:
            df1 = df1.merge(qr_data, on = "Quarter", how = "left")
        print("EEEE")
# Out:
# changed
# H&R BLOCK INC - EBITDA
# EEEE
# HABIT RESTAURANTS INC/THE-A - EBITDA
# EEEE
# HELEN OF TROY LTD - EBITDA
# EEEE
# HIBBETT SPORTS INC - EBITDA
# EEEE
# HILTON GRAND VACATIONS INC - EBITDA
# EEEE
# HOUGHTON MIFFLIN HARCOURT CO - EBITDA
# EEEE
# ILG LLC - EBITDA
# EEEE
# INSTALLED BUILDING PRODUCTS - EBITDA
# EEEE
# INTL SPEEDWAY CORP-CL A - EBITDA
# EEEE
# IROBOT CORP - EBITDA
# EEEE
# J.C. PENNEY CO INC - EBITDA
# EEEE
# JACK IN THE BOX INC - EBITDA
# EEEE
# K12 INC - EBITDA
# EEEE
# KB HOME - EBITDA
# EEEE
# LA QUINTA HOLDINGS INC - EBITDA
# EEEE
# LA-Z-BOY INC - EBITDA
# EEEE
# LANDS' END INC - EBITDA
# EEEE
# LAUREATE EDUCATION INC-A - EBITDA
# EEEE
# LCI INDUSTRIES - EBITDA
# EEEE
# LEGGETT & PLATT INC - EBITDA
# EEEE
# LIBERTY EXPEDIA HOLD-A - EBITDA
# EEEE
# LITHIA MOTORS INC-CL A - EBITDA
# EEEE
# LUMBER LIQUIDATORS HOLDINGS - EBITDA
# EEEE
# MARRIOTT VACATIONS WORLD - EBITDA
# EEEE
# MATTEL INC - EBITDA
# EEEE
# MDC HOLDINGS INC - EBITDA
# EEEE
# ...

# %%
df1.shape

# %%
df1.to_csv("/Users/akanksha_rajput/Documents/target3.csv")
